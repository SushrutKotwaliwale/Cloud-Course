# %% [markdown]
# <a href="https://colab.research.google.com/github/SushrutKotwaliwale/Cloud-Course/blob/main/Cloud_Computing_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def hello():
  return 'Hi'
hello()
# Out:
# 'Hi'

# %% [markdown]
# ##EDA

# %% [markdown]
# ##Conclusion
